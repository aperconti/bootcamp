# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Draisaitl scores four goals in Oilers win against Predators
# Forward, McDavid each has five points to help Edmonton gain in Pacific
# 2020-03-02
# -----------------
# Avalanche defeat Red Wings for seventh straight win
# Move within one point of first in Central Division; Makar misses game with upper-body injury
# 2020-03-02
# -----------------
# Emergency goalie procedure doesn't need change, GMs say
# Topic discussed at annual meetings after Ayres plays for Hurricanes
# 2020-03-02
# -----------------
# Rielly returns to practice with Maple Leafs, could play next week
# Defenseman has missed 20 games with broken foot
# 2020-03-02
# -----------------
# Fantasy forward top 100 rankings for 2019-20
# Fiala biggest riser from surprising Wild; Foligno, Buchnevich, Thomas join list
# 2020-03-02
# -----------------
# Penguins search for answers, look for ways to end six-game losing streak
# Try to have proper mindset heading into game against Senators
# 2020-03-02
# -----------------
# Panthers must fix issues before season slips away, GM says
# Tallon sounds alarm with Florida in danger of missing playoffs again
# 2020-03-02
# -----------------
# Brown accepts challenge of helping Kings through rebuild
# Two-time Stanley Cup champion aims to be part of the solution, example of winning culture
# 2020-03-02
# -----------------
# Laine could return for Jets against Sabres
# Forward has missed one game since hit in left foot by shot
# 2020-03-02
# -----------------
# NHL Fantasy on Ice podcast available now
# Playoff preview: schedule notes, pickups, fan questions; Stamkos, Stone injuries
# 2020-03-02
# -----------------
# Matthews, Marner break bread with Marleau Family on trip to Bay Area
# Maple Leafs forwards reunite with of new Penguins player on California trip
# 2020-03-02
# -----------------
# Rule changes having positive effect, NHL executives show general managers
# Decrease in coach's challenges among desired results helping game this season
# 2020-03-02
# -----------------
# Dumoulin, Marino could play for Penguins against Senators
# Forward Simon out week to week with upper-body injury
# 2020-03-02
# -----------------
# Anderson out 4-6 months for Blue Jackets after shoulder surgery
# Forward was injured against Senators on Dec. 14
# 2020-03-02
# -----------------
# NHL strength of schedule for rest of 2019-20
# Opponent points percentages (most to least favorable); games remaining splits
# 2020-03-02
# -----------------
# Color of Hockey: Mayers goes from NHL player to author
# Retired forward shares own experiences growing up in 'Hockey Is For Me' children's book
# 2020-03-02
# -----------------
# Erne could be out rest of season for Red Wings with broken hand
# Forward was injured blocking shot against Senators
# 2020-03-02
# -----------------
# Capitals to give away Wilson volleyball bobblehead at game vs. Blues
# Forward will resemble Hanks' friend from 'Cast Away' movie
# 2020-03-02
# -----------------
# Bruins-Lightning showdowns highlight week ahead
# Panthers retiring Luongo's No. 1 among can't-miss events
# 2020-03-02
# -----------------
# NHL DFS picks, projections, strategy
# Buchnevich on first power-play unit with Kreider out; more daily fantasy targets
# 2020-03-02
# -----------------
# Fiala leads 3 Stars of the Week
# Wild forward, Predators defenseman Ellis, Avalanche goalie Francouz earn honors
# 2020-03-02
# -----------------
# Rookie watch: Merzlikins best among first-year goalies, Weekes says
# Earns praise by NHL Network Analyst for keeping Blue Jackets in playoff contention
# 2020-03-02
# -----------------
# Gaudreau honors late grandfather with goal for Flames
# Forward opened scoring in win at Panthers, called it 'special time to find the net there'
# 2020-03-02
# -----------------
# Granato making strides for NHL Seattle as League's first female pro scout
# Hockey Hall of Famer helping expansion team get ready for 2021
# 2020-03-01
# -----------------
# Trophy Tracker: Hart
# Draisaitl, MacKinnon among favorites for MVP by NHL.com panel at three-quarters point
# 2020-03-01
# -----------------
# Stamkos out 6-8 weeks for Lightning, needs core muscle surgery
# Center, captain could return in first round of playoffs
# 2020-02-29
# -----------------
# Zuccarello clears puck by heading it out of defensive zone
# Wild forward used noggin to bump Galchenyuk's attempt to neutral ice
# 2020-03-01
# -----------------
# Ehlers makes big trade, tosses puck to fan for candy
# Jets forward puts on general manager's hat, likes deal he makes
# 2020-03-01
# -----------------
# Fantasy hockey top 10 waiver wire pickups
# Stalock worth adding from Wild; Backlund, Gurianov among best available forwards
# 2020-03-02
# -----------------
# March 2: Lemieux returns to Penguins after cancer treatments
# Plus: Selanne breaks rookie goal-scoring record; Blues win 10th straight road game
# 2020-03-02

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b194c'), 'header': 'Draisaitl scores four goals in Oilers win against Predators', 'subheader': 'Forward, McDavid each has five points to help Edmonton gain in Pacific', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b194d'), 'header': 'Avalanche defeat Red Wings for seventh straight win', 'subheader': 'Move within one point of first in Central Division; Makar misses game with upper-body injury', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b194e'), 'header': "Emergency goalie procedure doesn't need change, GMs say", 'subheader': 'Topic discussed at annual meetings after Ayres plays for Hurricanes', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b194f'), 'header': 'Rielly returns to practice with Maple Leafs, could play next week', 'subheader': 'Defenseman has missed 20 games with broken foot', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1950'), 'header': 'Fantasy forward top 100 rankings for 2019-20', 'subheader': 'Fiala biggest riser from surprising Wild; Foligno, Buchnevich, Thomas join list', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1951'), 'header': 'Penguins search for answers, look for ways to end six-game losing streak', 'subheader': 'Try to have proper mindset heading into game against Senators', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1952'), 'header': 'Panthers must fix issues before season slips away, GM says', 'subheader': 'Tallon sounds alarm with Florida in danger of missing playoffs again', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1953'), 'header': 'Brown accepts challenge of helping Kings through rebuild', 'subheader': 'Two-time Stanley Cup champion aims to be part of the solution, example of winning culture', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1954'), 'header': 'Laine could return for Jets against Sabres', 'subheader': 'Forward has missed one game since hit in left foot by shot', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1955'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Playoff preview: schedule notes, pickups, fan questions; Stamkos, Stone injuries', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1956'), 'header': 'Matthews, Marner break bread with Marleau Family on trip to Bay Area', 'subheader': 'Maple Leafs forwards reunite with of new Penguins player on California trip', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1957'), 'header': 'Rule changes having positive effect, NHL executives show general managers', 'subheader': "Decrease in coach's challenges among desired results helping game this season", 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1958'), 'header': 'Dumoulin, Marino could play for Penguins against Senators', 'subheader': 'Forward Simon out week to week with upper-body injury', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1959'), 'header': 'Anderson out 4-6 months for Blue Jackets after shoulder surgery', 'subheader': 'Forward was injured against Senators on Dec. 14', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195a'), 'header': 'NHL strength of schedule for rest of 2019-20', 'subheader': 'Opponent points percentages (most to least favorable); games remaining splits', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195b'), 'header': 'Color of Hockey: Mayers goes from NHL player to author', 'subheader': "Retired forward shares own experiences growing up in 'Hockey Is For Me' children's book", 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195c'), 'header': 'Erne could be out rest of season for Red Wings with broken hand', 'subheader': 'Forward was injured blocking shot against Senators', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195d'), 'header': 'Capitals to give away Wilson volleyball bobblehead at game vs. Blues', 'subheader': "Forward will resemble Hanks' friend from 'Cast Away' movie", 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195e'), 'header': 'Bruins-Lightning showdowns highlight week ahead', 'subheader': "Panthers retiring Luongo's No. 1 among can't-miss events", 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b195f'), 'header': 'NHL DFS picks, projections, strategy', 'subheader': 'Buchnevich on first power-play unit with Kreider out; more daily fantasy targets', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1960'), 'header': 'Fiala leads 3 Stars of the Week', 'subheader': 'Wild forward, Predators defenseman Ellis, Avalanche goalie Francouz earn honors', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1961'), 'header': 'Rookie watch: Merzlikins best among first-year goalies, Weekes says', 'subheader': 'Earns praise by NHL Network Analyst for keeping Blue Jackets in playoff contention', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1962'), 'header': 'Gaudreau honors late grandfather with goal for Flames', 'subheader': "Forward opened scoring in win at Panthers, called it 'special time to find the net there'", 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1963'), 'header': "Granato making strides for NHL Seattle as League's first female pro scout", 'subheader': 'Hockey Hall of Famer helping expansion team get ready for 2021', 'date': '2020-03-01'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1964'), 'header': 'Trophy Tracker: Hart', 'subheader': 'Draisaitl, MacKinnon among favorites for MVP by NHL.com panel at three-quarters point', 'date': '2020-03-01'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1965'), 'header': 'Stamkos out 6-8 weeks for Lightning, needs core muscle surgery', 'subheader': 'Center, captain could return in first round of playoffs', 'date': '2020-02-29'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1966'), 'header': 'Zuccarello clears puck by heading it out of defensive zone', 'subheader': "Wild forward used noggin to bump Galchenyuk's attempt to neutral ice", 'date': '2020-03-01'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1967'), 'header': 'Ehlers makes big trade, tosses puck to fan for candy', 'subheader': "Jets forward puts on general manager's hat, likes deal he makes", 'date': '2020-03-01'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1968'), 'header': 'Fantasy hockey top 10 waiver wire pickups', 'subheader': 'Stalock worth adding from Wild; Backlund, Gurianov among best available forwards', 'date': '2020-03-02'}
# {'_id': ObjectId('5e5ddda1b1b0e0523f1b1969'), 'header': 'March 2: Lemieux returns to Penguins after cancer treatments', 'subheader': 'Plus: Selanne breaks rookie goal-scoring record; Blues win 10th straight road game', 'date': '2020-03-02'}
