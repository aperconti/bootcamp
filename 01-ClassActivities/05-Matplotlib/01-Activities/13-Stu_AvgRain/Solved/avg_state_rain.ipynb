# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1999.2594004920254">
# ([<matplotlib.axis.XTick at 0x234ad8ad588>,
#   <matplotlib.axis.XTick at 0x234ae652588>,
#   <matplotlib.axis.XTick at 0x234ae65b248>,
#   <matplotlib.axis.XTick at 0x234adbd8688>,
#   <matplotlib.axis.XTick at 0x234adbd8dc8>,
#   <matplotlib.axis.XTick at 0x234adbdc6c8>,
#   <matplotlib.axis.XTick at 0x234adbe0108>,
#   <matplotlib.axis.XTick at 0x234adbe09c8>,
#   <matplotlib.axis.XTick at 0x234adbe5348>,
#   <matplotlib.axis.XTick at 0x234adbe5a88>,
#   <matplotlib.axis.XTick at 0x234adbdcf88>,
#   <matplotlib.axis.XTick at 0x234adbe9188>,
#   <matplotlib.axis.XTick at 0x234adbe9b48>,
#   <matplotlib.axis.XTick at 0x234adbec688>,
#   <matplotlib.axis.XTick at 0x234adbf0288>,
#   <matplotlib.axis.XTick at 0x234adbf0d48>,
#   <matplotlib.axis.XTick at 0x234adbf48c8>,
#   <matplotlib.axis.XTick at 0x234adbf9448>,
#   <matplotlib.axis.XTick at 0x234adbfc088>,
#   <matplotlib.axis.XTick at 0x234adbf9b88>,
#   <matplotlib.axis.XTick at 0x234adbfc748>,
#   <matplotlib.axis.XTick at 0x234adbfe1c8>,
#   <matplotlib.axis.XTick at 0x234adbfe848>,
#   <matplotlib.axis.XTick at 0x234adc02448>,
#   <matplotlib.axis.XTick at 0x234adc05088>,
#   <matplotlib.axis.XTick at 0x234adc05b08>,
#   <matplotlib.axis.XTick at 0x234adc0a688>,
#   <matplotlib.axis.XTick at 0x234adc0e288>,
#   <matplotlib.axis.XTick at 0x234adc0eb08>,
#   <matplotlib.axis.XTick at 0x234adc02e08>,
#   <matplotlib.axis.XTick at 0x234adc12248>,
#   <matplotlib.axis.XTick at 0x234adc12c08>,
#   <matplotlib.axis.XTick at 0x234adc14608>,
#   <matplotlib.axis.XTick at 0x234adc182c8>,
#   <matplotlib.axis.XTick at 0x234adc18e08>,
#   <matplotlib.axis.XTick at 0x234adc1c988>,
#   <matplotlib.axis.XTick at 0x234adc20508>,
#   <matplotlib.axis.XTick at 0x234adc23108>,
#   <matplotlib.axis.XTick at 0x234adc1ca08>,
#   <matplotlib.axis.XTick at 0x234adc23188>,
#   <matplotlib.axis.XTick at 0x234adc26248>,
#   <matplotlib.axis.XTick at 0x234adc26948>,
#   <matplotlib.axis.XTick at 0x234adc2a548>,
#   <matplotlib.axis.XTick at 0x234adc2e108>,
#   <matplotlib.axis.XTick at 0x234adc2ebc8>,
#   <matplotlib.axis.XTick at 0x234adc32748>,
#   <matplotlib.axis.XTick at 0x234adc352c8>,
#   <matplotlib.axis.XTick at 0x234adc35bc8>,
#   <matplotlib.axis.XTick at 0x234adc26c48>,
#   <matplotlib.axis.XTick at 0x234adc39248>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(6,15))
plt.barh(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.yticks(tick_locations, rain_df["State"])
# Out:
# <img src="data:image/png;base64,..." width="599.2593015924596">
# ([<matplotlib.axis.YTick at 0x234b845c608>,
#   <matplotlib.axis.YTick at 0x234b8456ac8>,
#   <matplotlib.axis.YTick at 0x234b8454708>,
#   <matplotlib.axis.YTick at 0x234b8506988>,
#   <matplotlib.axis.YTick at 0x234b8509708>,
#   <matplotlib.axis.YTick at 0x234b8509348>,
#   <matplotlib.axis.YTick at 0x234b850e548>,
#   <matplotlib.axis.YTick at 0x234b850ee88>,
#   <matplotlib.axis.YTick at 0x234b8513808>,
#   <matplotlib.axis.YTick at 0x234b8516208>,
#   <matplotlib.axis.YTick at 0x234b8516a88>,
#   <matplotlib.axis.YTick at 0x234b8518408>,
#   <matplotlib.axis.YTick at 0x234b8518d88>,
#   <matplotlib.axis.YTick at 0x234b851f908>,
#   <matplotlib.axis.YTick at 0x234b85166c8>,
#   <matplotlib.axis.YTick at 0x234b850ef08>,
#   <matplotlib.axis.YTick at 0x234b8522908>,
#   <matplotlib.axis.YTick at 0x234b8528308>,
#   <matplotlib.axis.YTick at 0x234b8528dc8>,
#   <matplotlib.axis.YTick at 0x234b852a9c8>,
#   <matplotlib.axis.YTick at 0x234b852d548>,
#   <matplotlib.axis.YTick at 0x234b8530148>,
#   <matplotlib.axis.YTick at 0x234b8530c08>,
#   <matplotlib.axis.YTick at 0x234b852aac8>,
#   <matplotlib.axis.YTick at 0x234b85093c8>,
#   <matplotlib.axis.YTick at 0x234b8536e48>,
#   <matplotlib.axis.YTick at 0x234b8538748>,
#   <matplotlib.axis.YTick at 0x234b853c348>,
#   <matplotlib.axis.YTick at 0x234b853ce48>,
#   <matplotlib.axis.YTick at 0x234b85419c8>,
#   <matplotlib.axis.YTick at 0x234b8545548>,
#   <matplotlib.axis.YTick at 0x234b8549148>,
#   <matplotlib.axis.YTick at 0x234b8549c08>,
#   <matplotlib.axis.YTick at 0x234b8545648>,
#   <matplotlib.axis.YTick at 0x234b854d488>,
#   <matplotlib.axis.YTick at 0x234b854db08>,
#   <matplotlib.axis.YTick at 0x234b8551508>,
#   <matplotlib.axis.YTick at 0x234b853b188>,
#   <matplotlib.axis.YTick at 0x234b853bc08>,
#   <matplotlib.axis.YTick at 0x234b8557788>,
#   <matplotlib.axis.YTick at 0x234b8559308>,
#   <matplotlib.axis.YTick at 0x234b8559e48>,
#   <matplotlib.axis.YTick at 0x234b853b208>,
#   <matplotlib.axis.YTick at 0x234b854dc48>,
#   <matplotlib.axis.YTick at 0x234b855c748>,
#   <matplotlib.axis.YTick at 0x234b8562488>,
#   <matplotlib.axis.YTick at 0x234b85631c8>,
#   <matplotlib.axis.YTick at 0x234b8563848>,
#   <matplotlib.axis.YTick at 0x234b8568488>,
#   <matplotlib.axis.YTick at 0x234b856c0c8>],
#  <a list of 50 Text yticklabel objects>)

# %%
plt.ylim(-0.25, len(x_axis))
plt.xlim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
plt.tight_layout()
